# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 613

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "https://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = f"q={city}&appid={weather_api_key}"
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(url+city_url).json()      

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | saipan
# Processing Record 2 of Set 1 | port elizabeth
# Processing Record 3 of Set 1 | waitangi
# Processing Record 4 of Set 1 | buhusi
# Processing Record 5 of Set 1 | mawlaik
# Processing Record 6 of Set 1 | port-aux-francais
# Processing Record 7 of Set 1 | qingdao
# Processing Record 8 of Set 1 | nuriootpa
# Processing Record 9 of Set 1 | ust-nera
# Processing Record 10 of Set 1 | port mathurin
# Processing Record 11 of Set 1 | edinburgh of the seven seas
# Processing Record 12 of Set 1 | tomatlan
# Processing Record 13 of Set 1 | pisco
# Processing Record 14 of Set 1 | whitehorse
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | anaconda
# Processing Record 17 of Set 1 | papatowai
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | ushuaia
# Processing Record 20 of Set 1 | jamestown
# Processing Record 21 of Set 1 | cabo san lucas
# Processing Record 22 of Set 1 | sabha
# Processing Record 23 of Set 1 | tosontsengel
# Processing Record 24 of Set 1 | puerto ayora
# Processing Record 25 of Set 1 | stanley
# Processing Record 26 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 27 of Set 1 | tiksi
# Processing Record 28 of Set 1 | adamstown
# Processing Record 29 of Set 1 | grytviken
# Processing Record 30 of Set 1 | afaahiti
# Processing Record 31 of Set 1 | valparaiso
# Processing Record 32 of Set 1 | blackmans bay
# Processing Record 33 of Set 1 | uturoa
# Processing Record 34 of Set 1 | margaret river
# Processing Record 35 of Set 1 | college
# Processing Record 36 of Set 1 | moriki
# Processing Record 37 of Set 1 | san luis de la loma
# Processing Record 38 of Set 1 | mezokovesd
# Processing Record 39 of Set 1 | xilin hot
# Processing Record 40 of Set 1 | thompson
# Processing Record 41 of Set 1 | dudinka
# Processing Record 42 of Set 1 | spirit lake
# Processing Record 43 of Set 1 | west island
# Processing Record 44 of Set 1 | carauari
# Processing Record 45 of Set 1 | komsomolets
# Processing Record 46 of Set 1 | malabrigo
# Processing Record 47 of Set 1 | labuan
# Processing Record 48 of Set 1 | sanctuary point
# Processing Record 49 of Set 1 | puerto natales
# Processing Record 50 of Set 1 | gilmer
# Processing Record 0 of Set 2 | merizo village
# Processing Record 1 of Set 2 | hermanus
# Processing Record 2 of Set 2 | iqaluit
# Processing Record 3 of Set 2 | sinabang
# Processing Record 4 of Set 2 | talakan
# Processing Record 5 of Set 2 | thunder bay
# Processing Record 6 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 7 of Set 2 | nar'yan-mar
# Processing Record 8 of Set 2 | bethel
# Processing Record 9 of Set 2 | borodino
# Processing Record 10 of Set 2 | ghat
# Processing Record 11 of Set 2 | nizhneangarsk
# Processing Record 12 of Set 2 | albany
# Processing Record 13 of Set 2 | dalbandin
# Processing Record 14 of Set 2 | esikhaleni
# Processing Record 15 of Set 2 | flying fish cove
# Processing Record 16 of Set 2 | acarau
# Processing Record 17 of Set 2 | chonchi
# Processing Record 18 of Set 2 | port douglas
# Processing Record 19 of Set 2 | qaqortoq
# Processing Record 20 of Set 2 | agnibilekrou
# Processing Record 21 of Set 2 | sao joao da barra
# Processing Record 22 of Set 2 | longyearbyen
# Processing Record 23 of Set 2 | al jawf
# Processing Record 24 of Set 2 | alotau
# City not found. Skipping...
# Processing Record 25 of Set 2 | kerikeri
# Processing Record 26 of Set 2 | yuktae-dong
# Processing Record 27 of Set 2 | chernigovka
# Processing Record 28 of Set 2 | vertientes
# Processing Record 29 of Set 2 | hawaiian paradise park
# Processing Record 30 of Set 2 | utrik
# Processing Record 31 of Set 2 | ixtapa
# Processing Record 32 of Set 2 | okap
# Processing Record 33 of Set 2 | palmas
# Processing Record 34 of Set 2 | mesolongi
# Processing Record 35 of Set 2 | hadibu
# Processing Record 36 of Set 2 | aasiaat
# Processing Record 37 of Set 2 | razole
# Processing Record 38 of Set 2 | coyhaique
# Processing Record 39 of Set 2 | isla mujeres
# Processing Record 40 of Set 2 | mossel bay
# Processing Record 41 of Set 2 | castillos
# Processing Record 42 of Set 2 | yinchuan
# Processing Record 43 of Set 2 | hobyo
# Processing Record 44 of Set 2 | enewetak
# Processing Record 45 of Set 2 | kotlas
# Processing Record 46 of Set 2 | invercargill
# Processing Record 47 of Set 2 | ormara
# Processing Record 48 of Set 2 | khandela
# Processing Record 49 of Set 2 | la'ie
# Processing Record 0 of Set 3 | aykhal
# Processing Record 1 of Set 3 | queenstown
# Processing Record 2 of Set 3 | carnarvon
# Processing Record 3 of Set 3 | hatillo
# Processing Record 4 of Set 3 | amstetten
# Processing Record 5 of Set 3 | ribeira grande
# Processing Record 6 of Set 3 | okhotsk
# Processing Record 7 of Set 3 | dalnegorsk
# Processing Record 8 of Set 3 | al ghayzah
# Processing Record 9 of Set 3 | koryazhma
# Processing Record 10 of Set 3 | avarua
# Processing Record 11 of Set 3 | san antonio de pale
# Processing Record 12 of Set 3 | port alfred
# Processing Record 13 of Set 3 | isafjordur
# Processing Record 14 of Set 3 | tonota
# Processing Record 15 of Set 3 | sittwe
# Processing Record 16 of Set 3 | klyuchi
# Processing Record 17 of Set 3 | posse
# Processing Record 18 of Set 3 | idri
# Processing Record 19 of Set 3 | ar ruways
# Processing Record 20 of Set 3 | rio grande
# Processing Record 21 of Set 3 | ihiala
# Processing Record 22 of Set 3 | hasaki
# Processing Record 23 of Set 3 | san patricio
# Processing Record 24 of Set 3 | santana
# Processing Record 25 of Set 3 | yarmouth
# Processing Record 26 of Set 3 | badger
# Processing Record 27 of Set 3 | toga village
# City not found. Skipping...
# Processing Record 28 of Set 3 | canutama
# Processing Record 29 of Set 3 | viedma
# Processing Record 30 of Set 3 | howrah
# Processing Record 31 of Set 3 | udachny
# Processing Record 32 of Set 3 | canton
# Processing Record 33 of Set 3 | i-n-salah
# Processing Record 34 of Set 3 | siwa oasis
# Processing Record 35 of Set 3 | aracati
# Processing Record 36 of Set 3 | mount pearl
# Processing Record 37 of Set 3 | cidreira
# Processing Record 38 of Set 3 | peresichna
# Processing Record 39 of Set 3 | miri
# Processing Record 40 of Set 3 | prado
# Processing Record 41 of Set 3 | saudarkrokur
# Processing Record 42 of Set 3 | vadso
# Processing Record 43 of Set 3 | egilsstadir
# Processing Record 44 of Set 3 | illizi
# Processing Record 45 of Set 3 | coos bay
# Processing Record 46 of Set 3 | hami
# Processing Record 47 of Set 3 | kapa'a
# Processing Record 48 of Set 3 | vorgashor
# Processing Record 49 of Set 3 | sretensk
# Processing Record 0 of Set 4 | midvagur
# Processing Record 1 of Set 4 | ilulissat
# Processing Record 2 of Set 4 | ulanhot
# Processing Record 3 of Set 4 | sao vicente
# Processing Record 4 of Set 4 | chihuahua
# Processing Record 5 of Set 4 | salinopolis
# Processing Record 6 of Set 4 | bandarbeyla
# Processing Record 7 of Set 4 | ciudad bolivar
# Processing Record 8 of Set 4 | gadzhiyevo
# Processing Record 9 of Set 4 | qianzhou
# Processing Record 10 of Set 4 | sola
# Processing Record 11 of Set 4 | guerrero negro
# Processing Record 12 of Set 4 | susuman
# Processing Record 13 of Set 4 | atafu village
# Processing Record 14 of Set 4 | goure
# Processing Record 15 of Set 4 | haiku-pauwela
# Processing Record 16 of Set 4 | bredasdorp
# Processing Record 17 of Set 4 | ibra'
# City not found. Skipping...
# Processing Record 18 of Set 4 | selkirk
# Processing Record 19 of Set 4 | chibougamau
# Processing Record 20 of Set 4 | natitingou
# Processing Record 21 of Set 4 | kone
# Processing Record 22 of Set 4 | holualoa
# Processing Record 23 of Set 4 | shorewood
# Processing Record 24 of Set 4 | bonadelle ranchos-madera ranchos
# Processing Record 25 of Set 4 | keflavik
# Processing Record 26 of Set 4 | abraham's bay
# City not found. Skipping...
# Processing Record 27 of Set 4 | vredendal
# Processing Record 28 of Set 4 | hotan
# Processing Record 29 of Set 4 | as sulayyil
# Processing Record 30 of Set 4 | ahau
# City not found. Skipping...
# Processing Record 31 of Set 4 | santa marta de ortigueira
# Processing Record 32 of Set 4 | anadyr
# Processing Record 33 of Set 4 | pacific grove
# Processing Record 34 of Set 4 | remire-montjoly
# Processing Record 35 of Set 4 | kilindoni
# Processing Record 36 of Set 4 | alghero
# Processing Record 37 of Set 4 | bilibino
# Processing Record 38 of Set 4 | rawson
# Processing Record 39 of Set 4 | tibati
# Processing Record 40 of Set 4 | ilha solteira
# Processing Record 41 of Set 4 | coahuayana de hidalgo
# Processing Record 42 of Set 4 | fale old settlement
# Processing Record 43 of Set 4 | labrador city
# Processing Record 44 of Set 4 | takoradi
# Processing Record 45 of Set 4 | el bauga
# Processing Record 46 of Set 4 | papao
# Processing Record 47 of Set 4 | pasighat
# Processing Record 48 of Set 4 | amarante do maranhao
# Processing Record 49 of Set 4 | zeya
# Processing Record 0 of Set 5 | kourou
# Processing Record 1 of Set 5 | cabedelo
# Processing Record 2 of Set 5 | hanceville
# Processing Record 3 of Set 5 | laojunmiao
# Processing Record 4 of Set 5 | lethem
# Processing Record 5 of Set 5 | betio village
# Processing Record 6 of Set 5 | arraial do cabo
# Processing Record 7 of Set 5 | tazacorte
# Processing Record 8 of Set 5 | masons bay
# City not found. Skipping...
# Processing Record 9 of Set 5 | baruun-urt
# Processing Record 10 of Set 5 | la ronge
# Processing Record 11 of Set 5 | umba
# Processing Record 12 of Set 5 | weno
# Processing Record 13 of Set 5 | antonio enes
# Processing Record 14 of Set 5 | broome
# Processing Record 15 of Set 5 | mayahi
# Processing Record 16 of Set 5 | stillwater
# Processing Record 17 of Set 5 | fort bragg
# Processing Record 18 of Set 5 | bokoro
# Processing Record 19 of Set 5 | jalqani
# Processing Record 20 of Set 5 | sitka
# Processing Record 21 of Set 5 | olonkinbyen
# Processing Record 22 of Set 5 | qamdo
# Processing Record 23 of Set 5 | voznesenskaya
# Processing Record 24 of Set 5 | nova sintra
# Processing Record 25 of Set 5 | harper
# Processing Record 26 of Set 5 | puerto baquerizo moreno
# Processing Record 27 of Set 5 | hilo
# Processing Record 28 of Set 5 | odienne
# Processing Record 29 of Set 5 | quellon
# Processing Record 30 of Set 5 | dunedin
# Processing Record 31 of Set 5 | el calafate
# Processing Record 32 of Set 5 | georgetown
# Processing Record 33 of Set 5 | murghob
# Processing Record 34 of Set 5 | viqueque
# Processing Record 35 of Set 5 | korla
# Processing Record 36 of Set 5 | kupang
# Processing Record 37 of Set 5 | codrington
# Processing Record 38 of Set 5 | dubti
# Processing Record 39 of Set 5 | oeiras do para
# Processing Record 40 of Set 5 | fortuna
# Processing Record 41 of Set 5 | wailua homesteads
# Processing Record 42 of Set 5 | nahiyat ash shinafiyah
# Processing Record 43 of Set 5 | alice springs
# Processing Record 44 of Set 5 | luanda
# Processing Record 45 of Set 5 | constantia
# Processing Record 46 of Set 5 | guateque
# Processing Record 47 of Set 5 | lata
# Processing Record 48 of Set 5 | sisimiut
# Processing Record 49 of Set 5 | mvomero
# Processing Record 0 of Set 6 | mao
# Processing Record 1 of Set 6 | nuuk
# Processing Record 2 of Set 6 | itamaraca
# Processing Record 3 of Set 6 | kiiminki
# Processing Record 4 of Set 6 | sakaiminato
# Processing Record 5 of Set 6 | richards bay
# Processing Record 6 of Set 6 | ambodifotatra
# Processing Record 7 of Set 6 | puerto penasco
# Processing Record 8 of Set 6 | guiuan
# Processing Record 9 of Set 6 | tsiombe
# Processing Record 10 of Set 6 | luderitz
# Processing Record 11 of Set 6 | genhe
# Processing Record 12 of Set 6 | lorengau
# Processing Record 13 of Set 6 | alesund
# Processing Record 14 of Set 6 | serenje
# Processing Record 15 of Set 6 | horta
# Processing Record 16 of Set 6 | kayangel
# Processing Record 17 of Set 6 | thurso
# Processing Record 18 of Set 6 | port lincoln
# Processing Record 19 of Set 6 | nueva gerona
# Processing Record 20 of Set 6 | mbaiki
# Processing Record 21 of Set 6 | kolonia
# Processing Record 22 of Set 6 | zhumysker
# Processing Record 23 of Set 6 | kapuskasing
# Processing Record 24 of Set 6 | chul'man
# Processing Record 25 of Set 6 | bamboo flat
# Processing Record 26 of Set 6 | guadalupe y calvo
# Processing Record 27 of Set 6 | woolgoolga
# Processing Record 28 of Set 6 | kodiak
# Processing Record 29 of Set 6 | colonia
# Processing Record 30 of Set 6 | aquiraz
# Processing Record 31 of Set 6 | iskateley
# Processing Record 32 of Set 6 | fuvahmulah
# City not found. Skipping...
# Processing Record 33 of Set 6 | mont-laurier
# Processing Record 34 of Set 6 | mount isa
# Processing Record 35 of Set 6 | sao tome
# Processing Record 36 of Set 6 | hirado
# Processing Record 37 of Set 6 | kaa-khem
# Processing Record 38 of Set 6 | taoudenni
# Processing Record 39 of Set 6 | lent'ekhi
# Processing Record 40 of Set 6 | zamora
# Processing Record 41 of Set 6 | sil-li
# Processing Record 42 of Set 6 | tura
# Processing Record 43 of Set 6 | xinyuan
# Processing Record 44 of Set 6 | nemuro
# Processing Record 45 of Set 6 | marsh harbour
# Processing Record 46 of Set 6 | st. john's
# Processing Record 47 of Set 6 | tweed heads
# Processing Record 48 of Set 6 | hondomachi-hondo
# Processing Record 49 of Set 6 | banikoara
# Processing Record 0 of Set 7 | vingt cinq
# City not found. Skipping...
# Processing Record 1 of Set 7 | griffith
# Processing Record 2 of Set 7 | cadale
# Processing Record 3 of Set 7 | taltal
# Processing Record 4 of Set 7 | prince rupert
# Processing Record 5 of Set 7 | durango
# Processing Record 6 of Set 7 | okigwe
# Processing Record 7 of Set 7 | cumaribo
# City not found. Skipping...
# Processing Record 8 of Set 7 | lebu
# Processing Record 9 of Set 7 | tadine
# Processing Record 10 of Set 7 | ust'-ilimsk
# Processing Record 11 of Set 7 | road town
# Processing Record 12 of Set 7 | shakawe
# Processing Record 13 of Set 7 | nguigmi
# Processing Record 14 of Set 7 | freetown
# Processing Record 15 of Set 7 | carutapera
# Processing Record 16 of Set 7 | talnakh
# Processing Record 17 of Set 7 | ataq
# Processing Record 18 of Set 7 | forster
# Processing Record 19 of Set 7 | ibaiti
# Processing Record 20 of Set 7 | warman
# Processing Record 21 of Set 7 | kulia village
# City not found. Skipping...
# Processing Record 22 of Set 7 | mar del plata
# Processing Record 23 of Set 7 | scottburgh
# Processing Record 24 of Set 7 | san julian
# Processing Record 25 of Set 7 | thinadhoo
# Processing Record 26 of Set 7 | vilhena
# Processing Record 27 of Set 7 | nadym
# Processing Record 28 of Set 7 | shimoda
# Processing Record 29 of Set 7 | powell river
# Processing Record 30 of Set 7 | nadi
# Processing Record 31 of Set 7 | mejit
# Processing Record 32 of Set 7 | galesong
# Processing Record 33 of Set 7 | margate
# Processing Record 34 of Set 7 | muzayri'
# City not found. Skipping...
# Processing Record 35 of Set 7 | huanta
# Processing Record 36 of Set 7 | vila franca do campo
# Processing Record 37 of Set 7 | fonadhoo
# City not found. Skipping...
# Processing Record 38 of Set 7 | gandi
# Processing Record 39 of Set 7 | nadvoitsy
# Processing Record 40 of Set 7 | midelt
# Processing Record 41 of Set 7 | tual
# Processing Record 42 of Set 7 | brisas de zicatela
# Processing Record 43 of Set 7 | barra do bugres
# Processing Record 44 of Set 7 | sabang
# Processing Record 45 of Set 7 | yemva
# Processing Record 46 of Set 7 | charters towers
# Processing Record 47 of Set 7 | key largo
# Processing Record 48 of Set 7 | ancud
# Processing Record 49 of Set 7 | puerto aysen
# Processing Record 0 of Set 8 | bao loc
# City not found. Skipping...
# Processing Record 1 of Set 8 | oroville east
# Processing Record 2 of Set 8 | soc trang
# Processing Record 3 of Set 8 | nili
# Processing Record 4 of Set 8 | hammerfest
# Processing Record 5 of Set 8 | bousso
# Processing Record 6 of Set 8 | ketchikan
# Processing Record 7 of Set 8 | manakara
# Processing Record 8 of Set 8 | mersa matruh
# Processing Record 9 of Set 8 | tumaco
# Processing Record 10 of Set 8 | orkney
# Processing Record 11 of Set 8 | gunjur
# Processing Record 12 of Set 8 | hirara
# Processing Record 13 of Set 8 | ad dilam
# Processing Record 14 of Set 8 | cargados carajos
# City not found. Skipping...
# Processing Record 15 of Set 8 | ulsteinvik
# Processing Record 16 of Set 8 | monopoli
# Processing Record 17 of Set 8 | marco island
# Processing Record 18 of Set 8 | campoverde
# Processing Record 19 of Set 8 | tralee
# Processing Record 20 of Set 8 | limon
# Processing Record 21 of Set 8 | san felipe
# Processing Record 22 of Set 8 | la rinconada
# Processing Record 23 of Set 8 | igrim
# Processing Record 24 of Set 8 | port-vila
# Processing Record 25 of Set 8 | tazovsky
# Processing Record 26 of Set 8 | port blair
# Processing Record 27 of Set 8 | opuwo
# Processing Record 28 of Set 8 | tevriz
# Processing Record 29 of Set 8 | staryye ozinki
# Processing Record 30 of Set 8 | coruripe
# Processing Record 31 of Set 8 | cherdakly
# Processing Record 32 of Set 8 | kailua-kona
# Processing Record 33 of Set 8 | guasdualito
# Processing Record 34 of Set 8 | labytnangi
# Processing Record 35 of Set 8 | trairi
# Processing Record 36 of Set 8 | trevelin
# Processing Record 37 of Set 8 | nogliki
# Processing Record 38 of Set 8 | sechura
# Processing Record 39 of Set 8 | antigonish
# Processing Record 40 of Set 8 | cannonvale
# Processing Record 41 of Set 8 | staunton
# Processing Record 42 of Set 8 | happy valley-goose bay
# Processing Record 43 of Set 8 | batangafo
# Processing Record 44 of Set 8 | boca chica
# Processing Record 45 of Set 8 | hayma'
# City not found. Skipping...
# Processing Record 46 of Set 8 | mahanje
# Processing Record 47 of Set 8 | itai
# Processing Record 48 of Set 8 | progreso
# Processing Record 49 of Set 8 | newman
# Processing Record 0 of Set 9 | wichita falls
# Processing Record 1 of Set 9 | luwuk
# Processing Record 2 of Set 9 | cruzeiro do sul
# Processing Record 3 of Set 9 | hazaribagh
# Processing Record 4 of Set 9 | akureyri
# Processing Record 5 of Set 9 | mana
# Processing Record 6 of Set 9 | kataragama
# City not found. Skipping...
# Processing Record 7 of Set 9 | haiphong
# Processing Record 8 of Set 9 | piti village
# Processing Record 9 of Set 9 | bubaque
# Processing Record 10 of Set 9 | struga
# Processing Record 11 of Set 9 | buritizeiro
# Processing Record 12 of Set 9 | namtsy
# Processing Record 13 of Set 9 | orivesi
# Processing Record 14 of Set 9 | caconda
# Processing Record 15 of Set 9 | sinop
# Processing Record 16 of Set 9 | mundri
# Processing Record 17 of Set 9 | walvis bay
# Processing Record 18 of Set 9 | ilha de mocambique
# Processing Record 19 of Set 9 | yangor
# City not found. Skipping...
# Processing Record 20 of Set 9 | curuca
# Processing Record 21 of Set 9 | ismailia
# Processing Record 22 of Set 9 | fabens
# Processing Record 23 of Set 9 | hamilton
# Processing Record 24 of Set 9 | safi
# Processing Record 25 of Set 9 | homer
# Processing Record 26 of Set 9 | zhaoyuan
# Processing Record 27 of Set 9 | nova borova
# Processing Record 28 of Set 9 | laguna
# Processing Record 29 of Set 9 | callao
# Processing Record 30 of Set 9 | letlhakeng
# Processing Record 31 of Set 9 | puerto asis
# Processing Record 32 of Set 9 | sur
# Processing Record 33 of Set 9 | benguela
# Processing Record 34 of Set 9 | kiruna
# Processing Record 35 of Set 9 | arar
# Processing Record 36 of Set 9 | fauske
# Processing Record 37 of Set 9 | port macquarie
# Processing Record 38 of Set 9 | kununurra
# Processing Record 39 of Set 9 | blitar
# Processing Record 40 of Set 9 | nelson
# Processing Record 41 of Set 9 | katsuura
# Processing Record 42 of Set 9 | sault ste. marie
# Processing Record 43 of Set 9 | ankazoabo
# Processing Record 44 of Set 9 | kuacjok
# Processing Record 45 of Set 9 | belmonte
# Processing Record 46 of Set 9 | la passe
# Processing Record 47 of Set 9 | buturlino
# Processing Record 48 of Set 9 | flin flon
# Processing Record 49 of Set 9 | buka
# Processing Record 0 of Set 10 | we
# City not found. Skipping...
# Processing Record 1 of Set 10 | kavaratti
# Processing Record 2 of Set 10 | noosa heads
# Processing Record 3 of Set 10 | wewak
# Processing Record 4 of Set 10 | contai
# Processing Record 5 of Set 10 | champerico
# Processing Record 6 of Set 10 | yaren
# Processing Record 7 of Set 10 | jodhpur
# Processing Record 8 of Set 10 | buncrana
# Processing Record 9 of Set 10 | hopelchen
# Processing Record 10 of Set 10 | afif
# Processing Record 11 of Set 10 | zefta
# Processing Record 12 of Set 10 | hovd
# Processing Record 13 of Set 10 | basni
# Processing Record 14 of Set 10 | lihue
# Processing Record 15 of Set 10 | lompoc
# Processing Record 16 of Set 10 | paphos
# Processing Record 17 of Set 10 | porto velho
# Processing Record 18 of Set 10 | puerto san carlos
# City not found. Skipping...
# Processing Record 19 of Set 10 | meadow lake
# Processing Record 20 of Set 10 | broken hill
# Processing Record 21 of Set 10 | joaima
# Processing Record 22 of Set 10 | bridgewater
# Processing Record 23 of Set 10 | geraldton
# Processing Record 24 of Set 10 | juan griego
# Processing Record 25 of Set 10 | praia da vitoria
# Processing Record 26 of Set 10 | ugoofaaru
# Processing Record 27 of Set 10 | masterton
# Processing Record 28 of Set 10 | trondheim
# Processing Record 29 of Set 10 | pimentel
# Processing Record 30 of Set 10 | sydney
# Processing Record 31 of Set 10 | saldanha
# Processing Record 32 of Set 10 | ocean pointe
# City not found. Skipping...
# Processing Record 33 of Set 10 | maymana
# Processing Record 34 of Set 10 | kingston
# Processing Record 35 of Set 10 | ponta delgada
# Processing Record 36 of Set 10 | arcachon
# Processing Record 37 of Set 10 | mosfellsbaer
# Processing Record 38 of Set 10 | petauke
# Processing Record 39 of Set 10 | mufulira
# Processing Record 40 of Set 10 | uvarovo
# Processing Record 41 of Set 10 | igarka
# Processing Record 42 of Set 10 | mugia
# Processing Record 43 of Set 10 | kidal
# Processing Record 44 of Set 10 | atherton
# Processing Record 45 of Set 10 | petropavlovsk-kamchatsky
# Processing Record 46 of Set 10 | kalaoa
# Processing Record 47 of Set 10 | tolanaro
# Processing Record 48 of Set 10 | ceerigaabo
# Processing Record 49 of Set 10 | kajaani
# Processing Record 0 of Set 11 | haifa
# Processing Record 1 of Set 11 | bartolome maso
# City not found. Skipping...
# Processing Record 2 of Set 11 | le mars
# Processing Record 3 of Set 11 | qingquan
# Processing Record 4 of Set 11 | volosovo
# Processing Record 5 of Set 11 | mont-dore
# Processing Record 6 of Set 11 | cobija
# Processing Record 7 of Set 11 | obo
# Processing Record 8 of Set 11 | dapa
# Processing Record 9 of Set 11 | pinoso
# Processing Record 10 of Set 11 | port augusta
# Processing Record 11 of Set 11 | majene
# Processing Record 12 of Set 11 | whyalla stuart
# City not found. Skipping...
# Processing Record 13 of Set 11 | bozeman
# Processing Record 14 of Set 11 | bukama
# Processing Record 15 of Set 11 | farshut
# Processing Record 16 of Set 11 | totness
# Processing Record 17 of Set 11 | sovetskoye
# Processing Record 18 of Set 11 | aripuana
# Processing Record 19 of Set 11 | santa cruz de tenerife
# Processing Record 20 of Set 11 | rio branco
# Processing Record 21 of Set 11 | alofi
# Processing Record 22 of Set 11 | howard springs
# Processing Record 23 of Set 11 | gushu
# Processing Record 24 of Set 11 | ulladulla
# Processing Record 25 of Set 11 | kristiansund
# Processing Record 26 of Set 11 | colipapa
# Processing Record 27 of Set 11 | ammon
# Processing Record 28 of Set 11 | puerto armuelles
# Processing Record 29 of Set 11 | camargo
# Processing Record 30 of Set 11 | khandud
# Processing Record 31 of Set 11 | conde
# Processing Record 32 of Set 11 | kirensk
# Processing Record 33 of Set 11 | polyarnyy
# Processing Record 34 of Set 11 | klaksvik
# Processing Record 35 of Set 11 | coquimbo
# Processing Record 36 of Set 11 | sironko
# Processing Record 37 of Set 11 | murtajapur
# Processing Record 38 of Set 11 | dickinson
# Processing Record 39 of Set 11 | naze
# Processing Record 40 of Set 11 | hithadhoo
# Processing Record 41 of Set 11 | lazaro cardenas
# Processing Record 42 of Set 11 | breaux bridge
# Processing Record 43 of Set 11 | beipiao
# Processing Record 44 of Set 11 | forbes
# Processing Record 45 of Set 11 | pariaman
# Processing Record 46 of Set 11 | filadelfia
# Processing Record 47 of Set 11 | north battleford
# Processing Record 48 of Set 11 | koungheul
# Processing Record 49 of Set 11 | bredy
# Processing Record 0 of Set 12 | shubarkuduk
# Processing Record 1 of Set 12 | zuyevka
# Processing Record 2 of Set 12 | ballesteros
# Processing Record 3 of Set 12 | gurupi
# Processing Record 4 of Set 12 | novozavedennoye
# Processing Record 5 of Set 12 | dubbo
# Processing Record 6 of Set 12 | mongar
# Processing Record 7 of Set 12 | quepos
# Processing Record 8 of Set 12 | lewistown
# Processing Record 9 of Set 12 | jutai
# Processing Record 10 of Set 12 | vilyuysk
# Processing Record 11 of Set 12 | robore
# Processing Record 12 of Set 12 | antsiranana
# Processing Record 13 of Set 12 | daru
# Processing Record 14 of Set 12 | mizdah
# Processing Record 15 of Set 12 | borba
# Processing Record 16 of Set 12 | gustavsberg
# Processing Record 17 of Set 12 | chiili
# City not found. Skipping...
# Processing Record 18 of Set 12 | boyolangu
# Processing Record 19 of Set 12 | yemetsk
# Processing Record 20 of Set 12 | mili
# Processing Record 21 of Set 12 | iquique
# Processing Record 22 of Set 12 | otjimbingwe
# Processing Record 23 of Set 12 | san pedro pochutla
# Processing Record 24 of Set 12 | umea
# Processing Record 25 of Set 12 | mount gambier
# Processing Record 26 of Set 12 | gua musang
# Processing Record 27 of Set 12 | tutong
# Processing Record 28 of Set 12 | bonthe
# Processing Record 29 of Set 12 | kangdong-up
# Processing Record 30 of Set 12 | alcacer do sal
# Processing Record 31 of Set 12 | kemijarvi
# Processing Record 32 of Set 12 | srivardhan
# Processing Record 33 of Set 12 | bereznik
# Processing Record 34 of Set 12 | uliastay
# Processing Record 35 of Set 12 | plastun
# Processing Record 36 of Set 12 | puerto san jose
# Processing Record 37 of Set 12 | naurskaya
# Processing Record 38 of Set 12 | jardim
# Processing Record 39 of Set 12 | peterhead
# Processing Record 40 of Set 12 | wamba
# Processing Record 41 of Set 12 | chivhu
# Processing Record 42 of Set 12 | sidney
# Processing Record 43 of Set 12 | honmachi
# Processing Record 44 of Set 12 | kurumkan
# Processing Record 45 of Set 12 | santa vitoria do palmar
# Processing Record 46 of Set 12 | kyren
# Processing Record 47 of Set 12 | navrongo
# Processing Record 48 of Set 12 | fortaleza
# Processing Record 49 of Set 12 | jerseyville
# Processing Record 0 of Set 13 | alaghsas
# Processing Record 1 of Set 13 | monki
# Processing Record 2 of Set 13 | padang
# Processing Record 3 of Set 13 | jinchang
# Processing Record 4 of Set 13 | itoman
# Processing Record 5 of Set 13 | mchinji
# Processing Record 6 of Set 13 | severo-yeniseyskiy
# Processing Record 7 of Set 13 | ascencion
# Processing Record 8 of Set 13 | las tablas
# Processing Record 9 of Set 13 | yeniseysk
# Processing Record 10 of Set 13 | chiva
# Processing Record 11 of Set 13 | zhangatas
# Processing Record 12 of Set 13 | betare oya
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          588
# Lat           588
# Lng           588
# Max Temp      588
# Humidity      588
# Cloudiness    588
# Wind Speed    588
# Country       588
# Date          588
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          saipan  15.1355  145.7010    301.54       100          40
# 1  port elizabeth -33.9180   25.5701    284.99        99          20
# 2        waitangi -43.9535 -176.5597    286.94        92          95
# 3          buhusi  46.7167   26.7000    297.72        85          78
# 4         mawlaik  23.6333   94.4167    299.56        70          72
#
#    Wind Speed Country        Date
# 0        5.14      MP  1685571633
# 1        2.06      ZA  1685571645
# 2        3.13      NZ  1685571627
# 3        1.88      RO  1685571776
# 4        0.50      MM  1685571776

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                    City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                saipan  15.1355  145.7010    301.54       100          40
# 1        port elizabeth -33.9180   25.5701    284.99        99          20
# 2              waitangi -43.9535 -176.5597    286.94        92          95
# 3                buhusi  46.7167   26.7000    297.72        85          78
# 4               mawlaik  23.6333   94.4167    299.56        70          72
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      MP  1685571633
# 1              2.06      ZA  1685571645
# 2              3.13      NZ  1685571627
# 3              1.88      RO  1685571776
# 4              0.50      MM  1685571776

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
plt.scatter(city_data_df["Max Temp"], city_data_df["Lat"])

# Incorporate the other graph properties
plt.title("City Max vs Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature(C)")

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(city_data_df["Humidity"], city_data_df["Lat"])

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity(%)")

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(city_data_df["Cloudiness"], city_data_df["Lat"])

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness(%)")

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(city_data_df["Wind Speed"], city_data_df["Lat"])

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed(m/s)")

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
def linear_regress(x, y, eqn_coordinates):
    r = st.pearsonr(x, y)
    print(f"The r-value is: {r[0]}")
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
    regress_values = x * slope + intercept
    line_eq = f"y ={slope: .2f}x +{intercept: .2f}"
    plt.plot(x, regress_values, "r-")
    plt.annotate(line_eq, eqn_coordinates, fontsize=12, color="red")
    plt.scatter(x, y)
    plt.xlabel(f"{x.name}")
    plt.ylabel(f"{y.name}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemisphere_df = city_data_df.loc[city_data_df["Lat"] >= 0]

# Display sample data
northern_hemisphere_df.head()
# Out:
#              City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          saipan  15.1355  145.7010    301.54       100          40
# 3          buhusi  46.7167   26.7000    297.72        85          78
# 4         mawlaik  23.6333   94.4167    299.56        70          72
# 6         qingdao  36.0986  120.3719    291.93        94          75
# 8        ust-nera  64.5667  143.2000    283.19        70          96
#
#          Wind Speed Country        Date
# City_ID
# 0              5.14      MP  1685571633
# 3              1.88      RO  1685571776
# 4              0.50      MM  1685571776
# 6              4.00      CN  1685571678
# 8              4.01      RU  1685571660

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemisphere_df = city_data_df.loc[city_data_df["Lat"] < 0]

# Display sample data
southern_hemisphere_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1           port elizabeth -33.9180   25.5701    284.99        99          20
# 2                 waitangi -43.9535 -176.5597    286.94        92          95
# 5        port-aux-francais -49.3500   70.2167    279.46        92         100
# 7                nuriootpa -34.4833  139.0000    288.28        87          72
# 9            port mathurin -19.6833   63.4167    297.16        65          15
#
#          Wind Speed Country        Date
# City_ID
# 1              2.06      ZA  1685571645
# 2              3.13      NZ  1685571627
# 5             13.35      TF  1685571621
# 7              1.36      AU  1685571777
# 9              5.85      MU  1685571640

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
linear_regress(northern_hemisphere_df["Lat"].rename("Latitude"), northern_hemisphere_df["Max Temp"], (10, -30))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[29], line 2
#       1 # Linear regression on Northern Hemisphere
# ----> 2 linear_regress(northern_hemisphere_df["Lat"].rename("Latitude"), northern_hemisphere_df["Max Temp"], (10, -30))
#
# Cell In[24], line 3, in linear_regress(x, y, eqn_coordinates)
#       2 def linear_regress(x, y, eqn_coordinates):
# ----> 3     r = st.pearsonr(x, y)
#       4     print(f"The r-value is: {r[0]}")
#       5     (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
#
# NameError: name 'st' is not defined

# %%
# Linear regression on Southern Hemisphere
linear_regress(southern_hemisphere_df["Lat"].rename("Latitude"), southern_hemisphere_df["Max Temp"], (-30, 8))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 2
#       1 # Linear regression on Southern Hemisphere
# ----> 2 linear_regress(southern_hemisphere_df["Lat"].rename("Latitude"), southern_hemisphere_df["Max Temp"], (-30, 8))
#
# Cell In[24], line 3, in linear_regress(x, y, eqn_coordinates)
#       2 def linear_regress(x, y, eqn_coordinates):
# ----> 3     r = st.pearsonr(x, y)
#       4     print(f"The r-value is: {r[0]}")
#       5     (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
#
# NameError: name 'st' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress(northern_hemisphere_df["Lat"].rename("Latitude"), northern_hemisphere_df["Max Temp"], (10, -30))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 2
#       1 # Northern Hemisphere
# ----> 2 linear_regress(northern_hemisphere_df["Lat"].rename("Latitude"), northern_hemisphere_df["Max Temp"], (10, -30))
#
# Cell In[24], line 3, in linear_regress(x, y, eqn_coordinates)
#       2 def linear_regress(x, y, eqn_coordinates):
# ----> 3     r = st.pearsonr(x, y)
#       4     print(f"The r-value is: {r[0]}")
#       5     (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
#
# NameError: name 'st' is not defined

# %%
# Southern Hemisphere
linear_regress(southern_hemisphere_df["Lat"].rename("Latitude"), southern_hemisphere_df["Humidity"], (-20, 50))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[32], line 2
#       1 # Southern Hemisphere
# ----> 2 linear_regress(southern_hemisphere_df["Lat"].rename("Latitude"), southern_hemisphere_df["Humidity"], (-20, 50))
#
# Cell In[24], line 3, in linear_regress(x, y, eqn_coordinates)
#       2 def linear_regress(x, y, eqn_coordinates):
# ----> 3     r = st.pearsonr(x, y)
#       4     print(f"The r-value is: {r[0]}")
#       5     (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
#
# NameError: name 'st' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress(northern_hemisphere_df["Lat"].rename("Latitude"), northern_hemisphere_df["Cloudiness"], (42, 50))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[33], line 2
#       1 # Northern Hemisphere
# ----> 2 linear_regress(northern_hemisphere_df["Lat"].rename("Latitude"), northern_hemisphere_df["Cloudiness"], (42, 50))
#
# Cell In[24], line 3, in linear_regress(x, y, eqn_coordinates)
#       2 def linear_regress(x, y, eqn_coordinates):
# ----> 3     r = st.pearsonr(x, y)
#       4     print(f"The r-value is: {r[0]}")
#       5     (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
#
# NameError: name 'st' is not defined

# %%
# Southern Hemisphere
linear_regress(southern_hemisphere_df["Lat"].rename("Latitude"), southern_hemisphere_df["Cloudiness"], (-50, 50))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[34], line 2
#       1 # Southern Hemisphere
# ----> 2 linear_regress(southern_hemisphere_df["Lat"].rename("Latitude"), southern_hemisphere_df["Cloudiness"], (-50, 50))
#
# Cell In[24], line 3, in linear_regress(x, y, eqn_coordinates)
#       2 def linear_regress(x, y, eqn_coordinates):
# ----> 3     r = st.pearsonr(x, y)
#       4     print(f"The r-value is: {r[0]}")
#       5     (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
#
# NameError: name 'st' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
linear_regress(northern_hemisphere_df["Lat"].rename("Latitude"), northern_hemisphere_df["Wind Speed"], (10, 12))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[35], line 2
#       1 # Northern Hemisphere
# ----> 2 linear_regress(northern_hemisphere_df["Lat"].rename("Latitude"), northern_hemisphere_df["Wind Speed"], (10, 12))
#
# Cell In[24], line 3, in linear_regress(x, y, eqn_coordinates)
#       2 def linear_regress(x, y, eqn_coordinates):
# ----> 3     r = st.pearsonr(x, y)
#       4     print(f"The r-value is: {r[0]}")
#       5     (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
#
# NameError: name 'st' is not defined

# %%
# Southern Hemisphere
linear_regress(southern_hemisphere_df["Lat"].rename("Latitude"), southern_hemisphere_df["Wind Speed"], (-50, 9))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[36], line 2
#       1 # Southern Hemisphere
# ----> 2 linear_regress(southern_hemisphere_df["Lat"].rename("Latitude"), southern_hemisphere_df["Wind Speed"], (-50, 9))
#
# Cell In[24], line 3, in linear_regress(x, y, eqn_coordinates)
#       2 def linear_regress(x, y, eqn_coordinates):
# ----> 3     r = st.pearsonr(x, y)
#       4     print(f"The r-value is: {r[0]}")
#       5     (slope, intercept, rvalue, pvalue, stderr) = linregress(x, y)
#
# NameError: name 'st' is not defined

# %% [markdown]
# **Discussion about the linear relationship:** YOUR RESPONSE HERE
